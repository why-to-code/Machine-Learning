# %%
# pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Series with list

# %%
nums = [10,20,30,40] # python list
s1 = pd.Series(nums)
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2 = pd.Series(nums,index=["a","b","c","d"]) # index parameter is used to change index number format.
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.shape
# Out:
# (4,)

# %%
len(s1)
# Out:
# 4

# %%
s1.ndim
# Out:
# 1

# %% [markdown]
# ### Series with dictionary

# %%
nums = {'a':10,'b':20,'c':30,'d':40}
nums
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
nums['a']
# Out:
# 10

# %%
s3 = pd.Series(nums)
s3
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s4 = pd.Series(nums , index=['a','c','d','b'])
s4
# Out:
# a    10
# c    30
# d    40
# b    20
# dtype: int64

# %%
s5 = pd.Series(nums,index=['a','b','e','c','d'])
s5
# Out:
# a    10.0
# b    20.0
# e     NaN
# c    30.0
# d    40.0
# dtype: float64

# %% [markdown]
# ### Extract element

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s1[0]
# Out:
# 10

# %%
s1[0:3] # last index excluded
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1[:3]
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1[1:]
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s1[-4:-2]
# Out:
# 0    10
# 1    20
# dtype: int64

# %% [markdown]
# ### Scaler operations

# %%
s2
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s2 + 5
# Out:
# a    15
# b    25
# c    35
# d    45
# dtype: int64

# %%
s2 - 4
# Out:
# a     6
# b    16
# c    26
# d    36
# dtype: int64

# %%
s2 * 3
# Out:
# a     30
# b     60
# c     90
# d    120
# dtype: int64

# %%
s2**2
# Out:
# a     100
# b     400
# c     900
# d    1600
# dtype: int64

# %%
s2 / 2
# Out:
# a     5.0
# b    10.0
# c    15.0
# d    20.0
# dtype: float64

# %% [markdown]
# ### Series arithmetic

# %%
s1 = pd.Series([34,46,43,23])
s2 = pd.Series([5,6,7,8])

# %%
s1
# Out:
# 0    34
# 1    46
# 2    43
# 3    23
# dtype: int64

# %%
s2
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
s1 + s2
# Out:
# 0    39
# 1    52
# 2    50
# 3    31
# dtype: int64

# %%
s1 * s2
# Out:
# 0    170
# 1    276
# 2    301
# 3    184
# dtype: int64

# %%
s1 / s2
# Out:
# 0    6.800000
# 1    7.666667
# 2    6.142857
# 3    2.875000
# dtype: float64

# %% [markdown]
# ### DataFrame with dictionary

# %%
students = {"Name":['Amit','Sam','Jhon'],"Age":[24,22,23]}

# %%
students
# Out:
# {'Name': ['Amit', 'Sam', 'Jhon'], 'Age': [24, 22, 23]}

# %%
students['Name']
# Out:
# ['Amit', 'Sam', 'Jhon']

# %%
students['Age']
# Out:
# [24, 22, 23]

# %%
student_df = pd.DataFrame(students)

# %%
student_df
# Out:
#    Name  Age
# 0  Amit   24
# 1   Sam   22
# 2  Jhon   23

# %%
student_df.ndim
# Out:
# 2

# %%
student_df.shape
# Out:
# (3, 2)

# %% [markdown]
# ### Reading csv file

# %%
startup_df = pd.read_csv("Startups.csv")

# %%
startup_df
# Out:
#     R&D Spend  Administration  Marketing Spend      State     Profit
# 0   165349.20       136897.80        471784.10  Bangalore  192261.83
# 1   162597.70       151377.59        443898.53     Mumbai  191792.06
# 2   153441.51       101145.55        407934.54      Delhi  191050.39
# 3   144372.41       118671.85        383199.62  Bangalore  182901.99
# 4   142107.34        91391.77        366168.42      Delhi  166187.94
# 5   131876.90        99814.71        362861.36  Bangalore  156991.12
# 6   134615.46       147198.87        127716.82     Mumbai  156122.51
# 7   130298.13       145530.06        323876.68      Delhi  155752.60
# 8   120542.52       148718.95        311613.29  Bangalore  152211.77
# 9   123334.88       108679.17        304981.62     Mumbai  149759.96
# 10  101913.08       110594.11        229160.95      Delhi  146121.95
# 11  100671.96        91790.61        249744.55     Mumbai  144259.40
# 12   93863.75       127320.38        249839.44      Delhi  141585.52
# ...

# %%
type(startup_df)
# Out:
# pandas.core.frame.DataFrame

# %%
startup_df.ndim
# Out:
# 2

# %%
startup_df.shape
# Out:
# (50, 5)

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
startup_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend      State     Profit
# 0  165349.20       136897.80        471784.10  Bangalore  192261.83
# 1  162597.70       151377.59        443898.53     Mumbai  191792.06
# 2  153441.51       101145.55        407934.54      Delhi  191050.39
# 3  144372.41       118671.85        383199.62  Bangalore  182901.99
# 4  142107.34        91391.77        366168.42      Delhi  166187.94

# %%
startup_df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend      State    Profit
# 45    1000.23       124153.04          1903.93  Bangalore  64926.08
# 46    1315.46       115816.21        297114.46      Delhi  49490.75
# 47       0.00       135426.92             0.00     Mumbai  42559.73
# 48     542.05        51743.15             0.00  Bangalore  35673.41
# 49       0.00       116983.80         45173.06     Mumbai  14681.40

# %%
startup_df.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend      State     Profit
# 0  165349.20       136897.80        471784.10  Bangalore  192261.83
# 1  162597.70       151377.59        443898.53     Mumbai  191792.06
# 2  153441.51       101145.55        407934.54      Delhi  191050.39
# 3  144372.41       118671.85        383199.62  Bangalore  182901.99
# 4  142107.34        91391.77        366168.42      Delhi  166187.94
# 5  131876.90        99814.71        362861.36  Bangalore  156991.12
# 6  134615.46       147198.87        127716.82     Mumbai  156122.51
# 7  130298.13       145530.06        323876.68      Delhi  155752.60
# 8  120542.52       148718.95        311613.29  Bangalore  152211.77
# 9  123334.88       108679.17        304981.62     Mumbai  149759.96

# %%
startup_df.tail(8)
# Out:
#     R&D Spend  Administration  Marketing Spend      State    Profit
# 42   23640.93        96189.63        148001.11     Mumbai  71498.49
# 43   15505.73       127382.30         35534.17  Bangalore  69758.98
# 44   22177.74       154806.14         28334.72     Mumbai  65200.33
# 45    1000.23       124153.04          1903.93  Bangalore  64926.08
# 46    1315.46       115816.21        297114.46      Delhi  49490.75
# 47       0.00       135426.92             0.00     Mumbai  42559.73
# 48     542.05        51743.15             0.00  Bangalore  35673.41
# 49       0.00       116983.80         45173.06     Mumbai  14681.40

# %%
startup_df
# Out:
#     R&D Spend  Administration  Marketing Spend      State     Profit
# 0   165349.20       136897.80        471784.10  Bangalore  192261.83
# 1   162597.70       151377.59        443898.53     Mumbai  191792.06
# 2   153441.51       101145.55        407934.54      Delhi  191050.39
# 3   144372.41       118671.85        383199.62  Bangalore  182901.99
# 4   142107.34        91391.77        366168.42      Delhi  166187.94
# 5   131876.90        99814.71        362861.36  Bangalore  156991.12
# 6   134615.46       147198.87        127716.82     Mumbai  156122.51
# 7   130298.13       145530.06        323876.68      Delhi  155752.60
# 8   120542.52       148718.95        311613.29  Bangalore  152211.77
# 9   123334.88       108679.17        304981.62     Mumbai  149759.96
# 10  101913.08       110594.11        229160.95      Delhi  146121.95
# 11  100671.96        91790.61        249744.55     Mumbai  144259.40
# 12   93863.75       127320.38        249839.44      Delhi  141585.52
# ...

# %%
startup_df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
startup_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend      State     Profit
# 0  165349.20       136897.80        471784.10  Bangalore  192261.83
# 1  162597.70       151377.59        443898.53     Mumbai  191792.06
# 2  153441.51       101145.55        407934.54      Delhi  191050.39
# 3  144372.41       118671.85        383199.62  Bangalore  182901.99
# 4  142107.34        91391.77        366168.42      Delhi  166187.94

# %%
profit = startup_df['Profit']

# %%
profit
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
startup_df[['Profit','State']]
# Out:
#        Profit      State
# 0   192261.83  Bangalore
# 1   191792.06     Mumbai
# 2   191050.39      Delhi
# 3   182901.99  Bangalore
# 4   166187.94      Delhi
# 5   156991.12  Bangalore
# 6   156122.51     Mumbai
# 7   155752.60      Delhi
# 8   152211.77  Bangalore
# 9   149759.96     Mumbai
# 10  146121.95      Delhi
# 11  144259.40     Mumbai
# 12  141585.52      Delhi
# 13  134307.35     Mumbai
# 14  132602.65      Delhi
# 15  129917.04  Bangalore
# 16  126992.93     Mumbai
# 17  125370.37  Bangalore
# 18  124266.90      Delhi
# 19  122776.86  Bangalore
# 20  118474.03     Mumbai
# 21  111313.02  Bangalore
# 22  110352.25      Delhi
# 23  108733.99      Delhi
# 24  108552.04  Bangalore
# 25  107404.34     Mumbai
# 26  105733.54      Delhi
# 27  105008.31  Bangalore
# 28  103282.38      Delhi
# 29  101004.64  Bangalore
# 30   99937.59      Delhi
# 31   97483.56  Bangalore
# 32   97427.84     Mumbai
# 33   96778.92      Delhi
# 34   96712.80     Mumbai
# 35   96479.51  Bangalore
# ...

# %%
st_df =startup_df

# %%
st_df.drop(['State','Profit'],axis=1) # drop column
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
st_df.drop([1,5,3]) # drop row
# Out:
#     R&D Spend  Administration  Marketing Spend      State     Profit
# 0   165349.20       136897.80        471784.10  Bangalore  192261.83
# 2   153441.51       101145.55        407934.54      Delhi  191050.39
# 4   142107.34        91391.77        366168.42      Delhi  166187.94
# 6   134615.46       147198.87        127716.82     Mumbai  156122.51
# 7   130298.13       145530.06        323876.68      Delhi  155752.60
# 8   120542.52       148718.95        311613.29  Bangalore  152211.77
# 9   123334.88       108679.17        304981.62     Mumbai  149759.96
# 10  101913.08       110594.11        229160.95      Delhi  146121.95
# 11  100671.96        91790.61        249744.55     Mumbai  144259.40
# 12   93863.75       127320.38        249839.44      Delhi  141585.52
# 13   91992.39       135495.07        252664.93     Mumbai  134307.35
# 14  119943.24       156547.42        256512.92      Delhi  132602.65
# 15  114523.61       122616.84        261776.23  Bangalore  129917.04
# ...

# %% [markdown]
# ### iloc

# %%
st_df
# Out:
#     R&D Spend  Administration  Marketing Spend      State     Profit
# 0   165349.20       136897.80        471784.10  Bangalore  192261.83
# 1   162597.70       151377.59        443898.53     Mumbai  191792.06
# 2   153441.51       101145.55        407934.54      Delhi  191050.39
# 3   144372.41       118671.85        383199.62  Bangalore  182901.99
# 4   142107.34        91391.77        366168.42      Delhi  166187.94
# 5   131876.90        99814.71        362861.36  Bangalore  156991.12
# 6   134615.46       147198.87        127716.82     Mumbai  156122.51
# 7   130298.13       145530.06        323876.68      Delhi  155752.60
# 8   120542.52       148718.95        311613.29  Bangalore  152211.77
# 9   123334.88       108679.17        304981.62     Mumbai  149759.96
# 10  101913.08       110594.11        229160.95      Delhi  146121.95
# 11  100671.96        91790.61        249744.55     Mumbai  144259.40
# 12   93863.75       127320.38        249839.44      Delhi  141585.52
# ...

# %%
st_df.iloc[4,3] # row,column
# Out:
# 'Delhi'

# %%
st_df.iloc[0:4,0:3]
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62

# %% [markdown]
# ### loc

# %%
st_df.loc[0:4,('R&D Spend','Administration','Profit')] # last index included
# Out:
#    R&D Spend  Administration     Profit
# 0  165349.20       136897.80  192261.83
# 1  162597.70       151377.59  191792.06
# 2  153441.51       101145.55  191050.39
# 3  144372.41       118671.85  182901.99
# 4  142107.34        91391.77  166187.94
