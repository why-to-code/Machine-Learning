# %% [markdown]
# # Pandas Function

# %%
import pandas as pd

# %%
data = {
    "Name":["Amit","Sam","Rohan"],
    "Age":[23,24,22]
}

df1 = pd.DataFrame(data)
df1
# Out:
#     Name  Age
# 0   Amit   23
# 1    Sam   24
# 2  Rohan   22

# %% [markdown]
# ## All()

# %%
df1.all() # checks column wise if all the values are True
# Out:
# Name    False
# Age      True
# dtype: bool

# %% [markdown]
# ## Any()

# %%
df1.any() # checks column wise if any one value is True
# Out:
# Name    True
# Age     True
# dtype: bool

# %% [markdown]
# ## Append

# %%
df1
# Out:
#    Name  Age
# 0  Amit   23
# 1   Sam   24
# 2         22

# %%
data1 = {
    "Name":['A','B','C'],
    "Age":[23,45,56]
} 

df2 = pd.DataFrame(data1)
df2
# Out:
#   Name  Age
# 0    A   23
# 1    B   45
# 2    C   56

# %%
 df1.append(df2)
# Out:
# /var/folders/_h/x4q09hy96pj_31bc_0s283j00000gp/T/ipykernel_93278/2709247757.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#    Name  Age
# 0  Amit   23
# 1   Sam   24
# 2         22
# 0     A   23
# 1     B   45
# 2     C   56

# %% [markdown]
# ## Assign

# %%
df1
# Out:
#     Name  Age
# 0   Amit   23
# 1    Sam   24
# 2  Rohan   22

# %%
df3 = df1.assign(phone=[2323434,4546,67668]) # add new column at last
df3
# Out:
#     Name  Age    phone
# 0   Amit   23  2323434
# 1    Sam   24     4546
# 2  Rohan   22    67668

# %% [markdown]
# ## Insert

# %%
df1
# Out:
#     Name  Age
# 0   Amit   23
# 1    Sam   24
# 2  Rohan   22

# %%
df1.insert(1,"Phone",[23456,6767686745,45645657])

# %%
df1
# Out:
#     Name       Phone  Age
# 0   Amit       23456   23
# 1    Sam  6767686745   24
# 2  Rohan    45645657   22

# %%
data_set = pd.read_csv("data.csv")
data_set
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data_set.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
pd.options.display.max_rows = 170

# %% [markdown]
# ## isna()

# %%
data_set['Calories'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
data_set[ data_set['Calories'].isna() ]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
data_set1 = data_set

# %% [markdown]
# ## dropna()

# %%
data_set2 = data_set1.dropna()

# %%
data_set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %% [markdown]
# ## fillna()

# %%
data_set1['Calories'].mean()
# Out:
# 375.79024390243904

# %%
data_set5 = data_set1.fillna(375)
data_set5
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     375.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
data_set5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
data_set5.empty
# Out:
# False

# %%
data_set5.equals(data_set2)
# Out:
# False

# %%
data_set1.filter(items = ['Duration','Calories'])
# Out:
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# 5          60     300.0
# 6          60     374.0
# 7          45     253.3
# 8          30     195.1
# 9          60     269.0
# 10         60     329.3
# 11         60     250.7
# 12         60     345.3
# 13         60     379.3
# 14         60     275.0
# 15         60     215.2
# 16         60     300.0
# 17         45       NaN
# 18         60     323.0
# 19         45     243.0
# 20         60     364.2
# 21         45     282.0
# 22         60     300.0
# 23         45     246.0
# 24         60     334.5
# 25         60     250.0
# 26         60     241.0
# 27         60       NaN
# 28         60     280.0
# 29         60     380.3
# 30         60     243.0
# 31         45     180.1
# 32         60     299.0
# 33         60     223.0
# 34         60     361.0
# 35         60     415.0
# 36         60     300.0
# ...

# %%
data_set1[['Duration','Calories']]
# Out:
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# 5          60     300.0
# 6          60     374.0
# 7          45     253.3
# 8          30     195.1
# 9          60     269.0
# 10         60     329.3
# 11         60     250.7
# 12         60     345.3
# 13         60     379.3
# 14         60     275.0
# 15         60     215.2
# 16         60     300.0
# 17         45       NaN
# 18         60     323.0
# 19         45     243.0
# 20         60     364.2
# 21         45     282.0
# 22         60     300.0
# 23         45     246.0
# 24         60     334.5
# 25         60     250.0
# 26         60     241.0
# 27         60       NaN
# 28         60     280.0
# 29         60     380.3
# 30         60     243.0
# 31         45     180.1
# 32         60     299.0
# 33         60     223.0
# 34         60     361.0
# 35         60     415.0
# 36         60     300.0
# ...

# %%
data_set1[ data_set1['Calories'] > 300  ]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 4          45    117       148     406.0
# 6          60    110       136     374.0
# 10         60    103       147     329.3
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 18         60    103       123     323.0
# 20         60    108       131     364.2
# 24         60    102       126     334.5
# 29         60    102       129     380.3
# 34         60    107       136     361.0
# 35         60    114       140     415.0
# 42         60    100       122     329.4
# 43         60    111       138     400.0
# 44         60    111       131     397.0
# 46         60    109       153     387.6
# 49         60    111       139     397.6
# 50         60    107       136     380.2
# 51         80    123       146     643.1
# 53         60    118       151     486.0
# ...
